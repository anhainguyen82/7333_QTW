# %% [markdown]
# # <div style="text-align:center"> DS7333 - Case Study 10 | Boston Housing Dataset</div>
# ### <div style="text-align:center">Andy Ho, An Nguyen, Jodi Pafford</div>
# <div style="text-align:center">July 15, 2019</div>

# %% [markdown]
# # Introduction
# ### The Boston Housing dataset contains information about the median value of owner-occupied homes in various areas of Boston, MA. In addition to the housing prices, other  attributes are also included (listed below).  The dataset itself is included in the scikit-learn python library.
#
# ### To get a baseline for comparison, we perform linear regression on the provided attributes to predict the price of each home.  Throughout this assignment, we imputed the dataset to observe how each imputation impacts the accuracy of prediction.  Two measures of accuracy is used: mean squared error (MSE) and goodness of fit (R2).
#
# ### In statistics, the mean squared error or mean squared deviation of an estimator measures the average of the squares of the errors—that is, the average squared difference between the estimated values and what is estimated. MSE is a risk function, corresponding to the expected value of the squared error loss (ref: https://en.wikipedia.org/wiki/Mean_squared_error). MSE allows us, in a single measurement, to capture the ideas of bias and variance in our models, as well as showing that there is some uncertainty in our models that we cannot get rid (ref: https://www.countbayesie.com/blog/2019/1/30/a-deeper-look-at-mean-squared-error).
#
# ### The goodness of fit of a statistical model describes how well it fits a set of observations. Measures of goodness of fit typically summarize the discrepancy between observed values and the values expected under the model in question (ref: https://en.wikipedia.org/wiki/Goodness_of_fit).  R-squared is always between 0 and 100%:
# - 0% indicates that the model explains none of the variability of the response data around its mean
# - 100% indicates that the model explains all the variability of the response data around its mean.
#
# ### Spoiler alert: The observed impacts of our data imputations were minimal on MSE and R2.  The below will provide explanations and results of each imputation.

# %% [markdown]
# ### Attribute Information:
#
#      1. CRIM      per capita crime rate by town
#
#      2. ZN        proportion of residential land zoned for lots over 25,000 sq.ft.
#
#      3. INDUS     proportion of non-retail business acres per town
#
#      4. CHAS      Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#
#      5. NOX       nitric oxides concentration (parts per 10 million)
#
#      6. RM        average number of rooms per dwelling
#
#      7. AGE       proportion of owner-occupied units built prior to 1940
#
#      8. DIS       weighted distances to five Boston employment centres
#
#      9. RAD       index of accessibility to radial highways
#
#      10. TAX      full-value property-tax rate per $10,000
#
#      11. PTRATIO  pupil-teacher ratio by town
#
#      12. B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#
#      13. LSTAT    % lower status of the population
#
#      14. PRICE     Median value of owner-occupied homes in $1000's

# %% [markdown]
# ### In this case study, we will look at the affect missing data has on linear regression when imputed. Missing Completely At Random, Missing At Random, and Missing Not At Random will all be investigated.

# %% [markdown]
# # Step 1: Linear Regression on data set with no NaN's

# %% [markdown]
# ### The complete Boston Housing data has a Mean Squared Error of 21.898 and a Goodness of Fit of 0.741 when applied to a simple linear regression model.

# %% [markdown]
# <h1><center>Step 1 Results</center></h1>
#
# | Method | Data | MSE | R2 |
# |:-:|:-:|:-:|:-:|
# | Original | No Data Imputed | 21.898 | 0.741 |
#
# <h3><center>Summary of Step 1 findings</center></h3>

# %% [markdown]
# # Step 2: Missing Completely At Random (MCAR) for 1%, 5%, 10%, 20%, 33%, and 50% of the data in a single column with imputation.
#
# ### We chose the LSTAT attribute to remove and impute. LSTAT is the % of lower status population (presumpuioiusly, the percent of the population that is lower class)

# %% [markdown]
# <h1><center>Step 2 Results</center></h1>
#
# | Method | Data | MSE | R2 |
# |:-:|:-:|:-:|:-:|
# |   1% MCAR  | LSTAT Imputed |   22.057  | 0.7387|
# |   5% MCAR   | LSTAT Imputed|   22.433  | 0.7343|
# |   10% MCAR   | LSTAT Imputed|  22.396  | 0.7347|
# |   20% MCAR   | LSTAT Imputed|  24.485  | 0.7100|
# |   33% MCAR   | LSTAT Imputed|  25.045  | 0.7033|
# |   50% MCAR   | LSTAT Imputed|  25.970  | 0.6924|
#
# <h3><center>Summary of Step 2 findings</center></h3>

# %% [markdown]
# # Step 3: Missing At Random (MAR) for 10%, 20%, and 30% of the data in a single column when controlled for a third variable with imputation.
#
# ### We chose the CRIM and ZN attribute when INDUS > 15 to remove and impute. CRIM= Per capita crime rate by town, ZN= Proprotion of residential land zoned for lots over 25,000 sq ft., and INDUS= Proportion of non-retail business acres per town.

# %% [markdown]
# <h1><center>Step 3 Results</center></h1>
#
# | Method | Data | MSE | R2 |
# |:-:|:-:|:-:|:-:|
# | 10% MAR | CRIM & ZN Imputed | 22.109 | 0.7381 |
# | 20% MAR | CRIM & ZN Imputed | 22.064 | 0.7386 |
# | 30% MAR | CRIM & ZN Imputed | 22.187 | 0.7372 |
#
# <h3><center>Summary of Step 3 findings</center></h3>

# %% [markdown]
# # Step 4: Missing Not At Random (MNAR) for 25% of the data in a single column with imputation.
#
# ### We chose the Age attribute. All values greater than 90 were removed and imputed with the mean. AGE= Percent of owner-occupied units who were built prior to 1940.

# %% [markdown]
# <h1><center>Step 4 Results</center></h1>
#
# | Method | Data | MSE | R2 |
# |:-:|:-:|:-:|:-:|
# | 25% MNAR | AGE Imputed | 22.238 | 0.7366 |
#
# <h3><center>Summary of Step 4 findings</center></h3>

# %% [markdown]
# # Conclusion
#
# ### As mentioned in the Introduction, the observed impact of our data imputations were minimal.  There are a few outliers that may need to be addressed (points lining vertical on the 50 value of x axis) but overall, we conclude the linear regressions performed were acceptable in predicting home prices for the Boston Housing dataset.
#
# ### For MSE, the min was 21.898 and max was 25.97.  Unlike R2, there is no hardset rule that the higher the value, the better the regression model.  Further analysis into bias-variance trade-offs would be required to observe uncertainties in our model.  Based on the range of MSE, our conclusion is each data imputation had relatively the same error as the base line simple linear regression model.
#
# ### For R2, the min was 0.6924 and max was 0.741.  In layman's term, the regression models accounts for variance between 69% and 74% which is moderately good.  Of course, the higher the R2 score, the better as it would indicate more variance was accounted meaning more price prediction falling on (or closer) to the regression line itself.

# %% [markdown]
# <h1><center> Results</center></h1>
#
# | Method | Data | MSE | R2 |
# |:-:|:-:|:-:|:-:|
# | Original | No Data Imputed | 21.898 | 0.741 |
# |   1% MCAR  | LSTAT Imputed |   22.057  | 0.7387|
# |   5% MCAR   | LSTAT Imputed|   22.433  | 0.7343|
# |   10% MCAR   | LSTAT Imputed|  22.396  | 0.7347|
# |   20% MCAR   | LSTAT Imputed|  24.485  | 0.7100|
# |   33% MCAR   | LSTAT Imputed|  25.045  | 0.7033|
# |   50% MCAR   | LSTAT Imputed|  25.970  | 0.6924|
# | 10% MAR | CRIM & ZN Imputed | 22.109 | 0.7381 |
# | 20% MAR | CRIM & ZN Imputed | 22.064 | 0.7386 |
# | 30% MAR | CRIM & ZN Imputed | 22.187 | 0.7372 |
# | 25% MNAR | AGE Imputed | 22.238 | 0.7366 |
#
# <h3><center>Summary of all findings</center></h3>

# %%
sns.lmplot('x', 'y', data=df, fit_reg=False, hue='Methods', scatter_kws={"marker":"D", "s":150})

plt.title('Summary of R2 Results')
plt.xlabel('R2 Scores')
plt.ylabel('% of Data Imputed')
plt.figtext(0.0, 0.01, "R2 Scores by missing value method and % of data imputed", ha='left')
plt.show()

# %% [markdown]
# ## Python Code for Case Study 10 -- Starts Here

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.datasets import load_boston
from sklearn.metrics import r2_score
import seaborn as sns; sns.set()

# %%
boston = load_boston()
bos = pd.DataFrame(boston.data)
bos.columns = boston.feature_names
bos['PRICE'] = boston.target

#Run to Pul Data into Excel
#bos.to_excel("Boston_Data.xlsx")

# %%
#Function to perform linear regression on data, compute MSE and Goodness of Fit
from sklearn.linear_model import LinearRegression

def Test(x, y, variable = [], control = [], percent = 0):
    
    lm = LinearRegression()
    lm.fit(x, y)
    Y_pred = lm.predict(x)
    if len(variable) == 0:
        txt = "Plot of prices vs predicted prices when 0% of data was replaced with 'NaN'."
    elif (len(variable) == 1) & (len(control) == 1) :
        txt = "Plot of prices vs predicted prices when " + str(percent) + "% of data in the " + \
              variable[0] + " column was replaced with 'NaN', only when " + control[0] + "." 
    elif len(variable) == 1:
        txt = "Plot of prices vs predicted prices when " + str(percent) + "% of data in the " + \
              variable[0] + " column was replaced with 'NaN'." 
    elif len(variable) > 1:
        txt = "Plot of prices vs predicted prices when " + str(percent) + "% of data in the " + \
              variable[0] + " and " + variable[1] + " column was replaced with 'NaN', only when " + \
              control[0] + "."


    plt.scatter(y, Y_pred)
    plt.xlabel("Prices: $Y_i$")
    plt.ylabel("Predicted prices: $\hat{Y}_i$")
    plt.title("Prices vs Predicted prices: $Y_i$ vs $\hat{Y}_i$")
    plt.text(0, -20, txt, ha='left')
    plt.show()
    
    mse = sklearn.metrics.mean_squared_error(y, Y_pred)
    print('MSE is:', mse)
    
    # R2 (Goodness of Fit)
    r2 = r2_score(Y, Y_pred)
    print('Goodness of Fit is:',r2)
    
    print('------------------')

# %%
#Step 1 - Fit a Linear Regressor to the data

#Split Target from Explanatory 
Y = bos['PRICE']
X = bos.drop('PRICE', axis = 1)
print("There are %i observations in the dependent variable, Y." %(Y.shape[0]))
print("There are %i observations and %i explanatory variables, X." %(X.shape[0], X.shape[1]))

Test(X,Y)
# Out:
# There are 506 observations in the dependent variable, Y.
# There are 506 observations and 13 explanatory variables, X.
# MSE is: 21.8977792176875
# Goodness of Fit is: 0.7406077428649427
# ------------------

# %%
#Step 2 - Missing Completely at Random
#LSTAT variable will be used for data replacement

import random

seed=2019  #set seed for reproducibility
random.seed(seed)
set_percent = [1, 5, 10, 20, 33, 50] #percent of data to be replaced with 'NaN'

for p in set_percent:
    bos_NaN = bos.copy()
    n=int(len(bos_NaN)*(p/100)) #calculate length of sample 
    index=random.sample(list(bos_NaN.index),n) #sample from index
    bos_NaN.LSTAT.iloc[index] = float('nan') #replace values with 'NaN'
    n_nan = sum(np.isnan(bos_NaN.LSTAT))
    bos_NaN.LSTAT=bos_NaN.LSTAT.fillna(bos_NaN.LSTAT.mean()) #impute 'NaN' with mean of variable
    
    Y = bos_NaN['PRICE']
    X = bos_NaN.drop('PRICE', axis = 1)
    
    print("")
    print("")
    print("There are %i observations in the dependent variable, Y." %(Y.shape[0]))
    print("There are %i observations and %i explanatory variables, X." %(X.shape[0], X.shape[1]))
    print("%i observations in the 'LSTAT' column was replaced with 'nan'." %(n_nan))
    print("Missing observations were replaced with the mean of the column, %i" %(bos_NaN.LSTAT.mean()))
    
    
    Test(X, Y, variable=['LSTAT'], percent=p)
# Out:
# There are 506 observations in the dependent variable, Y.
# There are 506 observations and 13 explanatory variables, X.
# 5 observations in the 'LSTAT' column was replaced with 'nan'.
# Missing observations were replaced with the mean of the column, 12
# MSE is: 22.057494336949727
# Goodness of Fit is: 0.7387158220051981
# ------------------
#
#
# There are 506 observations in the dependent variable, Y.
# There are 506 observations and 13 explanatory variables, X.
# 25 observations in the 'LSTAT' column was replaced with 'nan'.
# Missing observations were replaced with the mean of the column, 12
# MSE is: 22.432711821342885
# Goodness of Fit is: 0.7342711470805984
# ------------------
#
#
# There are 506 observations in the dependent variable, Y.
# There are 506 observations and 13 explanatory variables, X.
# 50 observations in the 'LSTAT' column was replaced with 'nan'.
# Missing observations were replaced with the mean of the column, 12
# MSE is: 22.39582690369592
# ...

# %%
#Step 3 - Missing at Random
#CRIM and ZN variable will be used for data replacement
#when controled for INDUS, bigger than 15

random.seed(seed)
set_percent = [10, 20, 30] #percent of data to be replaced with 'NaN'

for p in set_percent:
    bos_NaN = bos.copy()
    n=int(len(bos_NaN)*(p/100)) #calculate length of sample 
    index=random.sample(list(bos[bos.INDUS > 15].index),n) #sample from list of index where INDUS > 15
    bos_NaN.CRIM.iloc[index] = float('nan') #replace values with 'NaN'
    bos_NaN.ZN.iloc[index] = float('nan') #replace values with 'NaN'
    n_nan = [sum(np.isnan(bos_NaN.CRIM)), sum(np.isnan(bos_NaN.ZN))]
    
    bos_NaN.CRIM=bos_NaN.CRIM.fillna(bos_NaN.CRIM.mean()) #impute 'NaN' with mean of variable
    bos_NaN.ZN=bos_NaN.ZN.fillna(bos_NaN.ZN.mean()) #impute 'NaN' with mean of variable
    
    Y = bos_NaN['PRICE']
    X = bos_NaN.drop('PRICE', axis = 1)
    
    print("")
    print("")
    print("There are %i observations in the dependent variable, Y." %(Y.shape[0]))
    print("There are %i observations and %i explanatory variables, X." %(X.shape[0], X.shape[1]))
    print("%i and %i observations in the 'CRIM' and 'ZN' column, respectively, was replaced with 'nan'." %(n_nan[0], n_nan[1]))
    print("Missing observations in the 'CRIM' column were replaced with the mean of the column, %i" %(bos_NaN.CRIM.mean()))
    print("Missing observations in the 'ZN' column were replaced with the mean of the column, %i" %(bos_NaN.ZN.mean()))
    
    Test(X, Y, variable = ['CRIM', 'ZN'], control = ['INDUS > 15'], percent=p, )
# Out:
# There are 506 observations in the dependent variable, Y.
# There are 506 observations and 13 explanatory variables, X.
# 50 and 50 observations in the 'CRIM' and 'ZN' column, respectively, was replaced with 'nan'.
# Missing observations in the 'CRIM' column were replaced with the mean of the column, 2
# Missing observations in the 'ZN' column were replaced with the mean of the column, 12
# MSE is: 22.109181861480394
# Goodness of Fit is: 0.738103552444872
# ------------------
#
#
# There are 506 observations in the dependent variable, Y.
# There are 506 observations and 13 explanatory variables, X.
# 101 and 101 observations in the 'CRIM' and 'ZN' column, respectively, was replaced with 'nan'.
# Missing observations in the 'CRIM' column were replaced with the mean of the column, 2
# Missing observations in the 'ZN' column were replaced with the mean of the column, 14
# MSE is: 22.06421987938064
# Goodness of Fit is: 0.7386361539432331
# ------------------
#
#
# ...

# %%
#Step 4 - Missing Not at Random
#AGE variable will be used for data replacement

random.seed(seed)
set_percent = [25] #percent of data to be replaced with 'NaN'

for p in set_percent:
    bos_NaN = bos.copy()
    n=int(len(bos_NaN)*(p/100)) #calculate length of sample 
    index=random.sample(list(bos[bos.AGE > 90].index),n) #sample from index
    bos_NaN.AGE.iloc[index] = float('nan') #replace values with 'NaN'
    n_nan = sum(np.isnan(bos_NaN.AGE))
    bos_NaN.AGE=bos_NaN.AGE.fillna(bos_NaN.AGE.mean()) #impute 'NaN' with mean of variable
    
    Y = bos_NaN['PRICE']
    X = bos_NaN.drop('PRICE', axis = 1)
    
    print("")
    print("")
    print("There are %i observations in the dependent variable, Y." %(Y.shape[0]))
    print("There are %i observations and %i explanatory variables, X." %(X.shape[0], X.shape[1]))
    print("%i observations in the 'LSTAT' column was replaced with 'nan'." %(n_nan))
    print("Missing observations were replaced with the mean of the column, %i" %(bos_NaN.AGE.mean()))
    
    
    Test(X, Y, variable=['AGE'], control = ['AGE > 90'], percent=p)
# Out:
# There are 506 observations in the dependent variable, Y.
# There are 506 observations and 13 explanatory variables, X.
# 126 observations in the 'LSTAT' column was replaced with 'nan'.
# Missing observations were replaced with the mean of the column, 59
# MSE is: 21.89791816342794
# Goodness of Fit is: 0.7406060969697643
# ------------------

# %%
# Creating Summary Plot

import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import pandas as pd

df=pd.DataFrame()
df['y']=(0,1,5,10,20,33,50,10,20,30,25)
df['x']=(74.10, 73.87,73.43,73.47,71.00,70.33,69.24,73.81,73.86,73.72,73.66)
df['Methods']=("Original","MCAR","MCAR","MCAR","MCAR","MCAR","MCAR","MAR","MAR","MAR","MNAR")

sns.set_context("notebook", font_scale=1.5)
sns.set_style("ticks")

sns.lmplot('x', 'y', data=df, fit_reg=False, hue='Methods', scatter_kws={"marker":"D", "s":150})

plt.title('Summary of R2 Results')
plt.xlabel('R2 Scores')
plt.ylabel('% of Data Imputed')
print ("R2 Scores by missing value method and % of data imputed")
# Out:
# R2 Scores by missing value method and % of data imputed
