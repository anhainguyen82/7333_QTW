# %%
import tkinter
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
#import tensorflow as tf
#from tensorflow.keras import layers
#from tensorflow.keras import metrics
from sklearn import datasets
import pandas as pd
import numpy as np
import pandas_profiling as pp
import re

# %% [markdown]
# ## Load and Clean Data

# %%
# Read in CSV
df = pd.read_csv("final_project.csv")
print(len(df))
# Out:
# 160000

# %%
# Rename obvious columns
df.rename(columns={'x24': 'continent', 'x29': 'month', 'x30': 'day'}, inplace = True)
#list(df.columns)

# %%
# Correct misspellings and standardize values in labeled columns
df['continent'].replace('euorpe', 'europe',inplace=True)
df['month'].replace('Dev', '12',inplace=True)
df['month'].replace('Aug', '8',inplace=True)
df['month'].replace('Jun', '6',inplace=True)
df['month'].replace('Apr', '4',inplace=True)
df['month'].replace('Nov', '11',inplace=True)
df['month'].replace('sept.', '9',inplace=True)
df['month'].replace('Oct', '10',inplace=True)
df['month'].replace('Mar', '3',inplace=True)
df['month'].replace('January', '1',inplace=True)
df['month'].replace('Feb', '2',inplace=True)
df['month'].replace('May', '5',inplace=True)
df['month'].replace('July', '7',inplace=True)
df['month'].replace('December', '12',inplace=True)
df['month'].replace('August', '8',inplace=True)
df['month'].replace('June', '6',inplace=True)
df['month'].replace('April', '4',inplace=True)
df['month'].replace('November', '11',inplace=True)
df['month'].replace('September', '9',inplace=True)
df['month'].replace('October', '10',inplace=True)
df['month'].replace('March', '3',inplace=True)
df['day'].replace('thurday', 'thursday',inplace=True)


# Fill NA with 'other' in labeled columns
#df['continent'] = df['continent'].fillna('other')
#df['month'] = df['month'].fillna('other')
#df['day'] = df['day'].fillna('other')
#df['month'].replace('other','0', inplace=True)

# check unique values in labeled columns
print (df['continent'].unique())
print (df['month'].unique())
print (df['day'].unique())
# Out:
# ['europe' 'asia' 'america' nan]
# ['7' '8' '6' '5' '9' '4' '11' '10' nan '3' '2' '12' '1']
# ['tuesday' 'wednesday' 'thursday' 'monday' 'friday' nan]

# %%
# initialize temp for x37 column
temp_x37 = []

# Remove $ ) , characters and replace '(' with '-' 
for i in range (0,len(df)) :
    try :
        n = df['x37'][i]
        nstr = re.sub(r'[$|,|)]',r'', n)
        nstr = re.sub(r'[(]',r'-',nstr)
        #nstr= float(nstr)
        temp_x37.append(nstr)
    except :
        nstr = ''
        temp_x37.append(nstr)

# %%
# Verify len of both x37 matches
print(len(df['x37']))
print(len(temp_x37))

# Replace 'x37' with new values and convert to numeric
df['x37'] = temp_x37
df["x37"] = pd.to_numeric(df["x37"])
df['x37']
# Out:
# 160000
# 160000
# 0         1313.96
# 1         1962.78
# 2          430.47
# 3        -2366.29
# 4         -620.66
# 5         -196.45
# 6         -241.04
# 7          621.35
# 8         -301.89
# 9         -484.09
# 10        -106.65
# 11        -622.76
# 12         545.55
# 13        1019.08
# 14         960.95
# 15         299.52
# 16          72.83
# 17         -12.09
# 18        1074.27
# 19        -426.46
# 20        -710.18
# 21         370.01
# 22       -1199.52
# 23         -12.09
# 24        2158.38
# 25        -464.60
# 26        -526.08
# 27       -1321.42
# 28         771.15
# 29          41.97
#            ...
# 159970     954.38
# 159971     621.19
# 159972    1032.85
# 159973     729.11
# 159974    -167.10
# 159975     -33.14
# 159976    -409.63
# 159977    -126.15
# 159978     191.61
# 159979   -1356.91
# 159980     599.35
# 159981    -613.38
# 159982    2251.59
# 159983      -5.87
# 159984     198.30
# 159985   -1788.89
# 159986    -118.39
# 159987      15.62
# 159988     134.18
# 159989    -677.95
# 159990   -1012.45
# 159991   -1720.76
# 159992   -1177.33
# 159993    -818.32
# 159994    -823.35
# 159995    -891.96
# 159996    1588.65
# 159997     687.46
# 159998     439.21
# 159999   -1229.34
# Name: x37, Length: 160000, dtype: float64

# %%
# initialize temp for x32 column
temp_x32 = []

# Remove % ) , characters and replace '(' with '-' 
for i in range (0,len(df)) :
    try :
        n = df['x32'][i]
        nstr = re.sub(r'[%]',r'', n)
        #nstr = re.sub(r'[(]',r'-',nstr)
        #nstr= float(nstr)
        temp_x32.append(nstr)
    except :
        nstr = ''
        temp_x32.append(nstr)

# %%
# Verify len of both x32 matches
print(len(df['x32']))
print(len(temp_x32))

# Replace 'x32' with new values and convert to numeric
df['x32'] = temp_x32
df["x32"] = pd.to_numeric(df["x32"])
df['x32']
# Out:
# 160000
# 160000
# 0         0.00
# 1        -0.02
# 2        -0.01
# 3         0.01
# 4         0.01
# 5        -0.01
# 6        -0.01
# 7         0.01
# 8        -0.03
# 9         0.01
# 10        0.01
# 11        0.02
# 12        0.01
# 13       -0.01
# 14       -0.00
# 15       -0.01
# 16       -0.01
# 17       -0.00
# 18        0.00
# 19       -0.00
# 20       -0.02
# 21       -0.01
# 22        0.01
# 23       -0.00
# 24        0.00
# 25        0.02
# 26        0.01
# 27        0.01
# 28       -0.02
# 29        0.01
#           ...
# 159970   -0.01
# 159971   -0.01
# 159972    0.02
# 159973    0.01
# 159974    0.02
# 159975   -0.01
# 159976    0.00
# 159977    0.02
# 159978    0.01
# 159979   -0.00
# 159980   -0.01
# 159981   -0.00
# 159982   -0.02
# 159983   -0.00
# 159984   -0.01
# 159985    0.00
# 159986    0.01
# 159987    0.01
# 159988   -0.01
# 159989   -0.01
# 159990    0.00
# 159991    0.01
# 159992   -0.00
# 159993   -0.01
# 159994   -0.02
# 159995    0.00
# 159996   -0.01
# 159997   -0.00
# 159998   -0.02
# 159999    0.02
# Name: x32, Length: 160000, dtype: float64

# %%
# Subsetting data set by continent and print length of each
cont = ['asia', 'america','europe', 'other']

for n in cont :
    temp = df['continent'] == n
    df_temp = df[temp]
    #df_[n] = df_temp
    print (n, 'length is', len(df_temp))

# Subsetting by continent    
is_asia = df['continent']=='asia'
df_asia = df[is_asia]

is_europe = df['continent']=='europe'
df_europe = df[is_europe]

is_america = df['continent']=='america'
df_america = df[is_america]

is_other = df['continent']=='other'
df_other = df[is_other]
# Out:
# asia length is 138965
# america length is 4469
# europe length is 16538
# other length is 0

# %% [markdown]
# ## Explore Data

# %%
#Create new column for sum of all rows
df['Total']=df[['x0','x1','x2','x3','x4','x5','x6','x7','x8','x9','x10','x11','x12','x13','x14','x15','x16','x17','x18','x19','x20','x21','x22','x23','x25','x26','x27','x28','x31','x33','x34','x35','x36','x38','x39','x40','x41','x42','x43','x44','x45','x46','x47','x48','x49']].sum(axis=1)

# %%
df.head(3)
# Out:
#          x0        x1         x2        x3        x4         x5         x6  \
# 0 -0.166563 -3.961588   4.621113  2.481908 -1.800135   0.804684   6.718751
# 1 -0.149894 -0.585676  27.839856  4.152333  6.426802  -2.426943  40.477058
# 2 -0.321707 -1.429819  12.251561  6.586874 -5.304647 -11.311090  17.812850
#
#           x7        x8        x9  ...       x42       x43       x44       x45  \
# 0 -14.789997 -1.040673 -4.204950  ...  5.414063 -2.325655  1.674827 -0.264332
# 1  -6.725709  0.896421  0.330165  ...  4.490915  0.762561  6.526662  1.007927
# 2  11.060572  5.325880 -2.632984  ...  9.088864 -0.689886 -2.731118  0.754200
#
#          x46       x47       x48        x49  y       Total
# 0  60.781427 -7.689696  0.151589  -8.040166  0   39.629492
# 1  15.805696 -4.896678 -0.320283  16.719974  0  149.249956
# 2  30.856417 -7.428573 -2.090804  -7.869421  0   56.054797
#
# [3 rows x 52 columns]

# %%
#find all missing data
for x in df:
    try:
        index=df.index[np.isnan(df[x])]
    except:
        index=df.index[pd.isnull(df[x])]
        
    print(x)
    print(index)
    print("Amount missing:", len(index))
    print("Missing values from continent:")
    print(df['continent'][index].value_counts())
    print("")

#missing data are mostly from asian continent
# Out:
# x0
# Int64Index([  1282,   2290,   7491,  15484,  22497,  23192,  28954,  35999,
#              53729,  72318,  89922,  91019,  94393,  99268, 102350, 106226,
#             120560, 132472, 135679, 142823, 151123, 155246, 157238, 158239,
#             159224, 159524],
#            dtype='int64')
# Amount missing: 26
# Missing values from continent:
# asia       22
# europe      3
# america     1
# Name: continent, dtype: int64
#
# x1
# Int64Index([   269,   3904,  18170,  40299,  43772,  46051,  54302,  63871,
#              73401,  76946,  79935,  91884,  92187,  97060, 106076, 106931,
#             111839, 118680, 119489, 126167, 128371, 143211, 152513, 156865,
#             157417],
#            dtype='int64')
# Amount missing: 25
# Missing values from continent:
# asia      20
# europe     5
# Name: continent, dtype: int64
#
# x2
# Int64Index([  2524,   7138,  16032,  17062,  17148,  17641,  18440,  20228,
#              27683,  27959,  32870,  33648,  35077,  40394,  50604,  52640,
#              57254,  57369,  59119,  62709,  63383,  78075,  82015,  83543,
#              86861,  88464, 101372, 101568, 104777, 116080, 117351, 123214,
#             128539, 136189, 139289, 153417, 155054, 155388],
#            dtype='int64')
# Amount missing: 38
# Missing values from continent:
# asia      34
# europe     4
# Name: continent, dtype: int64
#
# x3
# Int64Index([  1915,   6601,   9826,  10834,  19377,  20312,  22997,  27191,
#              31962,  39640,  41322,  43215,  43262,  43778,  50217,  67362,
#              72150,  72800,  78537,  79155,  87910,  88941, 105051, 112588,
#             115585, 121126, 123428, 136869, 138962, 147037, 149073, 151926,
#             152732, 156561, 157827, 159475, 159830],
#            dtype='int64')
# Amount missing: 37
# Missing values from continent:
# asia       33
# europe      3
# america     1
# Name: continent, dtype: int64
#
# x4
# Int64Index([  6956,   8666,   9535,  14893,  15482,  21852,  29504,  31575,
#              32955,  60368,  62046,  66287,  72593,  87291,  99233,  99832,
#             109689, 113074, 117607, 120258, 120623, 130243, 135377, 137403,
#             143735, 158120],
#            dtype='int64')
# Amount missing: 26
# Missing values from continent:
# asia       19
# europe      4
# america     3
# Name: continent, dtype: int64
#
# x5
# Int64Index([  4395,   9825,  20869,  22027,  31222,  36879,  39806,  53541,
#              56519,  59824,  63040,  65736,  68001,  68552,  69871,  72759,
#              73322,  76663,  78768,  79130,  79957,  85579,  89203, 104427,
#             106452, 107487, 114312, 118722, 121267, 122527, 128311, 133413,
#             140829, 146547, 157095, 157264, 158277],
#            dtype='int64')
# Amount missing: 37
# Missing values from continent:
# asia       31
# europe      5
# america     1
# Name: continent, dtype: int64
#
# x6
# Int64Index([ 11392,  13613,  18494,  18522,  32999,  33860,  35660,  36355,
#              36872,  49312,  54331,  54590,  80772,  87098,  93541,  99452,
#             113268, 114659, 126399, 129319, 130411, 130645, 145548, 148616,
#             150775, 159014],
#            dtype='int64')
# Amount missing: 26
# Missing values from continent:
# asia       24
# america     1
# europe      1
# Name: continent, dtype: int64
#
# x7
# Int64Index([    48,   2467,   6172,  10206,  11677,  13716,  25873,  28028,
#              31866,  40731,  43670,  55400,  56037,  63788,  64243,  78500,
#              82440,  87258,  93748, 106357, 108730, 113741, 115064, 115750,
#             116276, 119916, 152897],
#            dtype='int64')
# Amount missing: 27
# Missing values from continent:
# asia       20
# europe      6
# america     1
# Name: continent, dtype: int64
#
# x8
# Int64Index([  2066,  12238,  13558,  14079,  19048,  19803,  25936,  41216,
#              44817,  44992,  62803,  70818,  73204,  76968,  93066,  93477,
#              94523,  97822, 101221, 115890, 157991],
#            dtype='int64')
# Amount missing: 21
# Missing values from continent:
# asia       17
# america     2
# europe      2
# Name: continent, dtype: int64
#
# x9
# Int64Index([  6015,  22252,  31459,  35865,  37777,  39047,  51360,  62568,
#              64412,  67659,  69570,  69582,  71001,  75883,  76074,  78531,
#              83688,  86952,  95350,  99874, 101076, 103787, 105549, 112556,
#             113355, 118333, 128953, 132304, 155272, 156576],
#            dtype='int64')
# Amount missing: 30
# Missing values from continent:
# asia      27
# europe     3
# Name: continent, dtype: int64
#
# x10
# Int64Index([  2315,   7132,   8935,  11853,  13971,  15352,  16457,  20326,
#              24956,  28246,  32662,  39921,  41706,  48193,  58548,  64630,
#              66039,  66104,  67043,  67246,  78042,  80997,  81139,  83274,
#              83769,  99401,  99462, 104870, 105517, 106869, 109587, 110821,
#             111472, 117559, 119661, 123244, 127475, 129078, 132336, 137295,
#             138166, 148115, 152281],
#            dtype='int64')
# Amount missing: 43
# Missing values from continent:
# asia       38
# europe      4
# america     1
# Name: continent, dtype: int64
#
# x11
# Int64Index([   721,   6506,   8563,  22104,  24255,  26625,  26676,  37927,
#              44715,  50656,  59892,  63877,  65043,  66501,  69326,  76311,
#              86759,  98088, 119189, 120452, 125420, 125704, 125976, 129243,
#             132593, 136175, 140064, 148790, 152207, 155157],
#            dtype='int64')
# Amount missing: 30
# Missing values from continent:
# asia       26
# europe      3
# america     1
# Name: continent, dtype: int64
#
# x12
# Int64Index([  1393,   2074,  12333,  14070,  17783,  22563,  23172,  32983,
#              33608,  36335,  36649,  42585,  46356,  48167,  50368,  55451,
#              58277,  60065,  62055,  66235,  67386,  72260,  73723,  79723,
#              80767,  88377,  91398,  98543, 107139, 123220, 124557, 125502,
#             130793, 133710, 138249, 147545],
#            dtype='int64')
# Amount missing: 36
# Missing values from continent:
# asia       30
# europe      4
# america     2
# Name: continent, dtype: int64
#
# x13
# Int64Index([   829,   1488,   2274,  15560,  23433,  23823,  26904,  32367,
#              32922,  36855,  38069,  42227,  56361,  77383,  78114,  78282,
#              88502,  89864,  97926, 109470, 113394, 120077, 121743, 123037,
#             126144, 126722, 147527, 154578, 155252, 155792, 159321],
#            dtype='int64')
# Amount missing: 31
# Missing values from continent:
# asia       26
# europe      3
# america     2
# Name: continent, dtype: int64
#
# x14
# Int64Index([  5801,   8943,   9592,  12291,  18653,  20221,  29131,  38393,
#              42483,  60992,  68804,  78890,  80662,  80960,  81097,  82265,
#              85909,  86774,  88935,  89230,  89268,  92893,  93381,  94814,
#             106125, 108708, 127550, 139886, 145495, 146052, 146088, 148104,
#             155281, 159834],
#            dtype='int64')
# Amount missing: 34
# Missing values from continent:
# asia      29
# europe     5
# Name: continent, dtype: int64
#
# x15
# Int64Index([  2992,   7566,  10058,  16121,  20001,  21820,  23419,  27909,
#              30231,  34410,  34424,  47194,  49051,  54152,  55408,  61003,
#              72557,  78803,  87140,  91890,  92242,  96769,  99856, 107039,
#             107040, 111759, 111931, 115757, 120733, 127990, 145368, 151296,
#             151431, 155690, 156942],
#            dtype='int64')
# Amount missing: 35
# Missing values from continent:
# asia      28
# europe     7
# Name: continent, dtype: int64
#
# x16
# Int64Index([  1461,  14149,  16477,  16543,  28096,  29432,  35980,  36866,
#              45891,  55057,  57402,  61526,  70192,  84247,  86089,  97180,
#             101336, 101367, 101431, 106266, 121841, 133256, 135320, 138611,
#             146715, 150983],
#            dtype='int64')
# Amount missing: 26
# Missing values from continent:
# asia      23
# europe     3
# Name: continent, dtype: int64
#
# x17
# Int64Index([  4875,  10431,  19173,  37443,  46005,  50022,  50871,  66812,
#              70213,  72319,  79659,  81844,  86881,  92088,  92220,  94130,
#             110263, 115906, 123285, 128541, 129492, 141561, 145541, 147798,
#             152498, 152644, 157325],
#            dtype='int64')
# Amount missing: 27
# Missing values from continent:
# asia       21
# europe      5
# america     1
# Name: continent, dtype: int64
#
# x18
# Int64Index([  9776,  11154,  15821,  23828,  26812,  27592,  28607,  35492,
#              41020,  41960,  45462,  53990,  57442,  59112,  60885,  62336,
#              63667,  64424,  69339,  73605,  77483,  79018,  83211,  95190,
#             100681, 102768, 110782, 112425, 119111, 119794, 128886, 129971,
#             131994, 134150, 146414, 147757, 148131, 149123, 156113, 156269],
#            dtype='int64')
# Amount missing: 40
# Missing values from continent:
# asia       33
# europe      4
# america     3
# Name: continent, dtype: int64
#
# x19
# Int64Index([  2207,   9369,  13241,  14906,  15419,  18886,  26709,  44393,
#              51558,  58743,  66180,  69259,  72490,  79258,  81186,  84593,
#              84903,  87091,  87595,  96089, 101282, 104493, 106986, 116377,
#             123987, 128502, 132167, 132302, 139517, 139798, 140407, 142698,
#             143022, 148756, 151032],
#            dtype='int64')
# Amount missing: 35
# Missing values from continent:
# asia      32
# europe     3
# Name: continent, dtype: int64
#
# x20
# Int64Index([   860,   2108,  10573,  12963,  14961,  27331,  32651,  36708,
#              38566,  38768,  39302,  44337,  45091,  45826,  58859,  60547,
#              70475,  74201,  76504,  77544,  79275,  79812,  81351,  87040,
#              88168,  92807,  95360, 104130, 108124, 124083, 124423, 125498,
#             129683, 135836, 136154, 138944, 140523, 149060],
#            dtype='int64')
# Amount missing: 38
# Missing values from continent:
# asia       33
# america     3
# europe      2
# Name: continent, dtype: int64
#
# x21
# Int64Index([  5149,  11550,  12172,  13036,  36250,  50784,  54085,  58561,
#              63432,  67694,  76566,  85780,  90515,  97392,  97950, 101523,
#             101874, 104515, 111133, 112637, 115722, 119035, 125470, 133879,
#             136139, 140374, 145501, 146392, 155763],
#            dtype='int64')
# Amount missing: 29
# Missing values from continent:
# asia       24
# europe      4
# america     1
# Name: continent, dtype: int64
#
# x22
# Int64Index([  3416,   5587,   5814,  12728,  16092,  27524,  27748,  35082,
#              37288,  37499,  42857,  48738,  53626,  59342,  59489,  61120,
#              77801,  86028,  93753, 105595, 116405, 122903, 128806, 131513,
#             151017, 151200, 154989],
#            dtype='int64')
# Amount missing: 27
# Missing values from continent:
# asia       23
# america     2
# europe      2
# Name: continent, dtype: int64
#
# x23
# Int64Index([   278,   6819,   7799,  10174,  10556,  13356,  14839,  16791,
#              18267,  21007,  28727,  31963,  33445,  34817,  35327,  36422,
#              38323,  39712,  40618,  48316,  53080,  55121,  63847,  69829,
#              88245,  88714,  88807,  89714,  90448,  95261,  95778,  97690,
#             102402, 103546, 109474, 110118, 110168, 111479, 126534, 127774,
#             128463, 131670, 137981, 145202, 147313, 156046, 157602],
#            dtype='int64')
# Amount missing: 47
# Missing values from continent:
# asia       42
# europe      4
# america     1
# Name: continent, dtype: int64
#
# continent
# Int64Index([  5210,  17289,  17844,  18156,  22032,  25611,  25820,  27941,
#              31112,  33247,  36301,  47431,  51910,  52603,  54785,  54955,
#              59593,  62410,  81989,  83384,  85138, 102261, 112268, 116123,
#             127761, 139910, 145990, 149398],
#            dtype='int64')
# Amount missing: 28
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x25
# Int64Index([  4420,  11485,  12718,  16021,  33294,  33311,  34286,  36782,
#              36833,  41497,  43755,  48910,  62789,  79327,  79703, 103897,
#             106611, 133558, 133780, 136610, 153094, 158137],
#            dtype='int64')
# Amount missing: 22
# Missing values from continent:
# asia      19
# europe     3
# Name: continent, dtype: int64
#
# x26
# Int64Index([  1504,  12350,  12670,  31058,  33444,  39734,  43578,  45326,
#              48065,  53661,  57592,  57749,  62761,  63668,  69919,  72893,
#              78735,  84153,  87521,  88117,  90835,  94268, 100831, 109270,
#             109522, 122753, 122879, 126477, 128186, 129540, 135629, 142614,
#             143594, 154775, 155426, 157105],
#            dtype='int64')
# Amount missing: 36
# Missing values from continent:
# asia      31
# europe     5
# Name: continent, dtype: int64
#
# x27
# Int64Index([  1631,   6161,   6783,  19499,  22633,  23604,  25902,  27532,
#              36684,  43059,  43818,  49585,  62007,  64458,  65301,  79615,
#              89401,  95579,  98220, 108101, 108631, 112599, 116860, 122068,
#             132594, 133341, 134751, 135572, 145355, 146266],
#            dtype='int64')
# Amount missing: 30
# Missing values from continent:
# asia      28
# europe     2
# Name: continent, dtype: int64
#
# x28
# Int64Index([ 11772,  13572,  13915,  15490,  18684,  24801,  27147,  30392,
#              32839,  37399,  54044,  60959,  71135,  73824,  80592,  83227,
#              83544,  85266,  88574,  95643,  97035, 101825, 103169, 104348,
#             106132, 113050, 114314, 114465, 115849, 118184, 121213, 145893,
#             152647, 152715, 159533],
#            dtype='int64')
# Amount missing: 35
# Missing values from continent:
# asia       27
# europe      6
# america     2
# Name: continent, dtype: int64
#
# month
# Int64Index([   126,   1614,   9240,  20372,  20593,  29277,  35972,  40002,
#              43631,  49444,  61382,  64487,  76507,  79378,  80364,  86058,
#              88273,  99809, 112737, 113443, 116869, 119751, 126939, 129666,
#             130135, 138585, 138723, 139065, 149747, 158046],
#            dtype='int64')
# Amount missing: 30
# Missing values from continent:
# asia       28
# america     1
# europe      1
# Name: continent, dtype: int64
#
# day
# Int64Index([  3445,   8374,  15130,  18824,  23650,  30794,  37275,  52210,
#              52677,  53827,  58934,  75787,  77640,  78329,  94867,  97610,
#              98781, 101589, 111110, 111326, 111331, 117494, 122053, 130671,
#             131938, 137988, 141529, 145022, 151419, 154052],
#            dtype='int64')
# Amount missing: 30
# Missing values from continent:
# asia       27
# europe      2
# america     1
# Name: continent, dtype: int64
#
# x31
# Int64Index([  6839,  11077,  11937,  14138,  18308,  30465,  34002,  35909,
#              38964,  42340,  44927,  45579,  53783,  55182,  60025,  74966,
#              81592,  82431,  82450,  85011, 100395, 102392, 107695, 118947,
#             119855, 124158, 125623, 129283, 135216, 139256, 141680, 143454,
#             143725, 145058, 148512, 151179, 156849, 157287, 159511],
#            dtype='int64')
# Amount missing: 39
# Missing values from continent:
# asia       33
# america     3
# europe      3
# Name: continent, dtype: int64
#
# x32
# Int64Index([   544,  13156,  15663,  19101,  28860,  31436,  40829,  52420,
#              59970,  61578,  62073,  65967,  70206,  70749,  73468,  73510,
#              75161,  86460,  91512, 101117, 103767, 106389, 109491, 120840,
#             123455, 123658, 130041, 134803, 140865, 141548, 159103],
#            dtype='int64')
# Amount missing: 31
# Missing values from continent:
# asia      30
# europe     1
# Name: continent, dtype: int64
#
# x33
# Int64Index([  2802,   3615,  13182,  17075,  25731,  31456,  32522,  34510,
#              34939,  38908,  47141,  50571,  54504,  58333,  60761,  66459,
#              72331,  74156,  75226,  83164,  88931,  89269,  94642,  98487,
#             109721, 117473, 118119, 121027, 121106, 121233, 125209, 130998,
#             134036, 135512, 140871, 141552, 144858, 145429, 146774, 155463,
#             156361],
#            dtype='int64')
# Amount missing: 41
# Missing values from continent:
# asia       35
# europe      5
# america     1
# Name: continent, dtype: int64
#
# x34
# Int64Index([  6129,  12691,  13903,  37565,  40176,  41645,  45358,  45813,
#              52066,  57062,  64241,  64459,  68479,  69310,  73177,  78429,
#              79355,  80146,  80198,  81931,  88041,  89989,  95530,  99781,
#             104443, 104512, 112967, 116171, 116857, 125745, 128163, 129747,
#             130908, 132645, 132657, 135464, 136510, 136556, 142625, 150362,
#             157419],
#            dtype='int64')
# Amount missing: 41
# Missing values from continent:
# asia       38
# america     2
# europe      1
# Name: continent, dtype: int64
#
# x35
# Int64Index([   335,  10938,  11563,  12922,  13551,  24689,  25259,  30404,
#              37005,  38819,  42331,  48238,  58792,  59043,  67130,  71824,
#              72648,  85227,  88094,  88214,  92548,  93469,  99148, 113832,
#             123454, 127500, 128969, 133922, 134920, 143225],
#            dtype='int64')
# Amount missing: 30
# Missing values from continent:
# asia       27
# europe      2
# america     1
# Name: continent, dtype: int64
#
# x36
# Int64Index([  4443,   4936,  16986,  18056,  21657,  23336,  30753,  42392,
#              43442,  53373,  56110,  56115,  56869,  67451,  70334,  71190,
#              77425,  81452,  88654,  92441,  98540, 101079, 120142, 120582,
#             133140, 138183, 143789],
#            dtype='int64')
# Amount missing: 27
# Missing values from continent:
# asia       22
# europe      3
# america     2
# Name: continent, dtype: int64
#
# x37
# Int64Index([   185,   3981,  14339,  38686,  48684,  49644,  54591,  56410,
#              57687,  64015,  68439,  76760,  78969,  79058,  79072,  79518,
#              84494,  91192,  92156, 110480, 112005, 135182, 142371],
#            dtype='int64')
# Amount missing: 23
# Missing values from continent:
# asia       20
# america     2
# europe      1
# Name: continent, dtype: int64
#
# x38
# Int64Index([  3961,   6588,   6652,  22592,  28274,  39895,  42369,  42891,
#              44843,  48794,  49769,  52012,  63472,  65033,  67463,  68035,
#              70337,  72477,  82340,  85246,  87461,  89139, 100685, 105951,
#             116264, 122638, 123909, 127910, 147220, 153213, 153377],
#            dtype='int64')
# Amount missing: 31
# Missing values from continent:
# asia       26
# europe      4
# america     1
# Name: continent, dtype: int64
#
# x39
# Int64Index([   151,   5914,  12708,  22718,  37008,  55047,  63802,  64461,
#              73800,  76711,  86241,  89726,  91026, 103028, 104456, 109362,
#             124849, 127939, 136797, 138468, 143045, 143121, 145381],
#            dtype='int64')
# Amount missing: 23
# Missing values from continent:
# asia      21
# europe     2
# Name: continent, dtype: int64
#
# x40
# Int64Index([  4267,  10199,  14969,  18768,  22457,  23903,  35161,  36863,
#              40488,  51470,  55884,  58409,  68532,  69711,  75398,  76670,
#              80210,  86359,  92286,  94162,  94235, 103038, 107308, 112594,
#             113935, 120207, 123268, 128145, 130600, 133708, 133946, 140362,
#             144510, 145553, 150510, 153985],
#            dtype='int64')
# Amount missing: 36
# Missing values from continent:
# asia    36
# Name: continent, dtype: int64
#
# x41
# Int64Index([  6314,   9536,  16560,  19284,  23132,  34349,  36629,  49185,
#              52544,  53474,  56828,  57204,  58141,  64950,  65486,  68821,
#              69693,  72607,  77716,  78982,  84461,  84492,  92646,  93042,
#             101257, 101387, 108243, 110211, 124963, 128360, 133458, 136974,
#             143694, 144085, 147398, 147766, 153362, 153432, 154427, 158400],
#            dtype='int64')
# Amount missing: 40
# Missing values from continent:
# asia       35
# europe      4
# america     1
# Name: continent, dtype: int64
#
# x42
# Int64Index([  2494,   4228,   4772,  23255,  26607,  32642,  40927,  43380,
#              49524,  51425,  76903,  91217,  92487,  94308, 101345, 101763,
#             115814, 119873, 127762, 129706, 129950, 138745, 151207, 154062,
#             156135, 156369],
#            dtype='int64')
# Amount missing: 26
# Missing values from continent:
# asia      24
# europe     2
# Name: continent, dtype: int64
#
# x43
# Int64Index([    29,   3524,   4970,   5684,  13028,  20368,  24509,  27516,
#              31096,  31734,  35466,  40327,  40796,  41518,  43500,  45530,
#              47715,  47921,  49640,  63488,  63803,  73689,  75765,  77761,
#              84538,  88681,  90329,  97010,  99623, 106142, 119769, 140737,
#             143009, 145496, 151591, 156045, 157527],
#            dtype='int64')
# Amount missing: 37
# Missing values from continent:
# asia       34
# europe      2
# america     1
# Name: continent, dtype: int64
#
# x44
# Int64Index([  3002,   3153,   7744,  13533,  15542,  21866,  22397,  25457,
#              31983,  34119,  34766,  37640,  41946,  42096,  42343,  53432,
#              59445,  63630,  64151,  69053,  70888,  75353,  79686,  81378,
#              97845, 113044, 118507, 121580, 122394, 130086, 136018, 140442,
#             141118, 143017, 146192, 148630, 150572, 153447, 156720, 159374],
#            dtype='int64')
# Amount missing: 40
# Missing values from continent:
# asia       34
# europe      5
# america     1
# Name: continent, dtype: int64
#
# x45
# Int64Index([   152,   7009,  10601,  17400,  18272,  18658,  23031,  30350,
#              39519,  51766,  54180,  62196,  64136,  70618,  74579,  91844,
#              94108, 110236, 113488, 115816, 118780, 123889, 124268, 130643,
#             135598, 137478, 151606, 153878, 155512],
#            dtype='int64')
# Amount missing: 29
# Missing values from continent:
# asia       25
# europe      3
# america     1
# Name: continent, dtype: int64
#
# x46
# Int64Index([  5986,  15394,  17276,  17463,  21677,  22519,  25655,  27282,
#              30730,  45264,  51003,  68146,  70134,  75479,  79838,  80685,
#              81049,  81731,  87176,  90108,  93637, 106812, 115968, 119302,
#             123188, 125646, 132187, 142066, 151513, 154570, 158486],
#            dtype='int64')
# Amount missing: 31
# Missing values from continent:
# asia       25
# europe      5
# america     1
# Name: continent, dtype: int64
#
# x47
# Int64Index([  3739,   6941,   7859,  11606,  12729,  15791,  18711,  28961,
#              29417,  30472,  32702,  35692,  43748,  50616,  54001,  54701,
#              55913,  61273,  62673,  68271,  74060,  76794,  82796,  83187,
#              83495,  89699,  98480,  98666, 100788, 101159, 110946, 122487,
#             129830, 131082, 141359, 144463, 149808],
#            dtype='int64')
# Amount missing: 37
# Missing values from continent:
# asia       31
# europe      5
# america     1
# Name: continent, dtype: int64
#
# x48
# Int64Index([ 27313,  31049,  41838,  45142,  47606,  50266,  50511,  55186,
#              61932,  71892,  73251,  74962,  77976,  78381,  81562,  84529,
#              90297,  92256,  95370,  98842, 100883, 102685, 103703, 105165,
#             121703, 125947, 134620, 146390, 151866, 155334, 155940, 159785],
#            dtype='int64')
# Amount missing: 32
# Missing values from continent:
# asia      30
# europe     2
# Name: continent, dtype: int64
#
# x49
# Int64Index([  3504,  11513,  15652,  25357,  38310,  41711,  45062,  50655,
#              51528,  53598,  81863,  82788,  95837,  97007, 100910, 104207,
#             104998, 106635, 107260, 117108, 122519, 123499, 124061, 134207,
#             136518, 139799, 140146, 142472, 143754, 145154, 145866, 153252],
#            dtype='int64')
# Amount missing: 32
# Missing values from continent:
# asia       28
# america     2
# europe      2
# Name: continent, dtype: int64
#
# y
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# Total
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)

# %%
is_asia = df['continent']=='asia'
df_asia = df[is_asia]

pp.ProfileReport(df_asia)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>53 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>138965 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>56.2 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>424.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>47 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>3 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_continent"><code>continent</code></a> has constant value asia <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_x32"><code>x32</code></a> has 57820 / 41.6% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_x41"><code>x41</code></a> is highly correlated with <a href="#pp_var_x38"><code>x38</code></a> (ρ = 1) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_x6"><code>x6</code></a> is highly correlated with <a href="#pp_var_x2"><code>x2</code></a> (ρ = 1) <span class="label label-primary">Rejected</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_Total">Total<br/>
#             <small>Numeric</small>
#         </p>
#     </div><div class="col-md-6">
#     <div class="row">
#         <div class="col-sm-6">
#             <table class="stats ">
#                 <tr>
#                     <th>Distinct count</th>
#                     <td>138965</td>
#                 </tr>
#                 <tr>
#                     <th>Unique (%)</th>
#                     <td>100.0%</t

# %%
#get mean of variables from asia if variable contains numbers, exclude 'NaN'
#get most occuring values of variables from asia if variable contains strings, exclude nulls
impute_values = {}
for x in df:
    if x != 'continent':
        try:
            impute_values[x] = df_asia[~np.isnan(df_asia[x])][x].mean()
        except:
            impute_values[x] = df_asia[~pd.isnull(df_asia[x])][x].max()
            
#impute NaN and nulls with values obtained from above         
for x in df:
    if x != 'continent':
        try:
            index=df.index[np.isnan(df[x])]
        except:
            index=df.index[pd.isnull(df[x])]
        df[x][index] = impute_values[x]
# Out:
# C:\Users\anhai\AppData\Local\conda\conda\envs\Python 3.5\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#find all missing data
for x in df:
    try:
        index=df.index[np.isnan(df[x])]
    except:
        index=df.index[pd.isnull(df[x])]
        
    print(x)
    print(index)
    print("Amount missing:", len(index))
    print("Missing values from continent:")
    print(df['continent'][index].value_counts())
    print("")

#missing data are mostly from asian continent
# Out:
# x0
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x1
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x2
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x3
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x4
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x5
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x6
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x7
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x8
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x9
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x10
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x11
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x12
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x13
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x14
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x15
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x16
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x17
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x18
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x19
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x20
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x21
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x22
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x23
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# continent
# Int64Index([  5210,  17289,  17844,  18156,  22032,  25611,  25820,  27941,
#              31112,  33247,  36301,  47431,  51910,  52603,  54785,  54955,
#              59593,  62410,  81989,  83384,  85138, 102261, 112268, 116123,
#             127761, 139910, 145990, 149398],
#            dtype='int64')
# Amount missing: 28
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x25
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x26
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x27
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x28
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# month
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# day
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x31
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x32
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x33
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x34
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x35
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x36
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x37
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x38
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x39
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x40
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x41
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x42
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x43
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x44
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x45
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x46
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x47
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x48
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x49
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# y
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# Total
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)

# %%
#remove all observations with missing 'continent' data
df = df[~pd.isnull(df['continent'])]

# %%
#find all missing data
for x in df:
    try:
        index=df.index[np.isnan(df[x])]
    except:
        index=df.index[pd.isnull(df[x])]
        
    print(x)
    print(index)
    print("Amount missing:", len(index))
    print("Missing values from continent:")
    print(df['continent'][index].value_counts())
    print("")

#missing data are mostly from asian continent
# Out:
# x0
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x1
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x2
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x3
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x4
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x5
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x6
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x7
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x8
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x9
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x10
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x11
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x12
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x13
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x14
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x15
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x16
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x17
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x18
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x19
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x20
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x21
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x22
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x23
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# continent
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x25
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x26
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x27
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x28
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# month
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# day
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x31
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x32
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x33
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x34
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x35
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x36
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x37
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x38
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x39
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x40
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x41
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x42
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x43
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x44
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x45
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x46
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x47
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x48
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# x49
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# y
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)
#
# Total
# Int64Index([], dtype='int64')
# Amount missing: 0
# Missing values from continent:
# Series([], Name: continent, dtype: int64)

# %%
pp.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>53 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>159972 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>64.7 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>424.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>47 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>3 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_x32"><code>x32</code></a> has 64406 / 40.3% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_x41"><code>x41</code></a> is highly correlated with <a href="#pp_var_x38"><code>x38</code></a> (ρ = 0.99976) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_x6"><code>x6</code></a> is highly correlated with <a href="#pp_var_x2"><code>x2</code></a> (ρ = 0.99973) <span class="label label-primary">Rejected</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_Total">Total<br/>
#             <small>Numeric</small>
#         </p>
#     </div><div class="col-md-6">
#     <div class="row">
#         <div class="col-sm-6">
#             <table class="stats ">
#                 <tr>
#                     <th>Distinct count</th>
#                     <td>159972</td>
#                 </tr>
#                 <tr>
#                     <th>Unique (%)</th>
#                     <td>100.0%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Missing (%)</th>
#                     <td

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

df_PCA = df.copy()

#variables to be drop
#categoricals ('continent', 'day', 'month')
#highly correlated ('x6', 'x41')
#derived ('Total')
#target ('y')
r_variables = ['continent', 'day', 'month', 'x6', 'x41', 'Total', 'y']

target = df_PCA['y']
#drop variables
explainatory = df_PCA.drop(r_variables, axis=1)

# split data into training and test set
train, test, train_target, test_target = train_test_split( explainatory, target, test_size=.2, random_state=0)

#scale explanatory variables (mean = 0, variance = 1)
scaler = StandardScaler().fit(train)

# Apply transform to both the training set and the test set.
train = scaler.transform(train)
test = scaler.transform(test)

# %%
from sklearn.decomposition import PCA

pca = PCA().fit(train)
pca_t = pca.transform(train)

# %%
import matplotlib.pyplot as plt

#plot component 1 vs component 2
f = plt.figure()
plt.scatter(pca_t[:, 0], pca_t[:, 1], c=train_target, marker='.', cmap='jet')
plt.title('PC2 vs PC1')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')

f.savefig("scatter.png", bbox_inches='tight')
# Out:
# C:\Users\anhai\AppData\Local\conda\conda\envs\Python 3.5\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.

# %%
# Source: https://towardsdatascience.com/an-approach-to-choosing-the-number-of-components-in-a-principal-component-analysis-pca-3b9f3d6e73fe

#Plotting the Cumulative Summation of the Explained Variance
f = plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('Explained Variance')

f.savefig("variance.png", bbox_inches='tight')
# Out:
# C:\Users\anhai\AppData\Local\conda\conda\envs\Python 3.5\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
