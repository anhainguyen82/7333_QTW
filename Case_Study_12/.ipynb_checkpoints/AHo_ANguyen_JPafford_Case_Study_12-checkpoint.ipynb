# %%
import tensorflow as tf
from tensorflow.keras import layers
from sklearn import datasets
import pandas as pd
import numpy as np
print(tf.__version__)
# Out:
# 1.10.0

# %%
#Load Data
bos = pd.read_csv('HIGGS.csv', names=["Target", "lepton_pT", "lepton_eta", "lepton_phi",
                                      "missing_energy_magnitude", "missing_energy_phi", "jet_1_pt",
                                      "jet_1_eta", "jet_1_phi", "jet_1_b-tag", "jet_2_pt", "jet_2_eta", "jet_2_phi",
                                      "jet_2_b-tag", "jet_3_pt", "jet_3_eta", "jet_3_phi", "jet_3_b-tag", "jet_4_pt",
                                      "jet_4_eta", "jet_4_phi", "jet_4_b-tag", "m_jj", "m_jjj", "m_lv", "m_jlv", "m_bb",
                                      "m_wbb", "m_wwbb"])

# %%
#bos.head()

y = bos['Target'][:1050000]
x = bos.drop('Target', axis = 1)
x = x[:1050000]

# %%
print(len(x))
print(len(y))
# Out:
# 1050000
# 1050000

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_train = scaler.fit_transform(x)

# Print out the adjustment that the scaler applied to the total_earnings column of data
print("Note: median values were scaled by multiplying by {:.10f} and adding {:.6f}".format(scaler.scale_[12], scaler.min_[12]))
multiplied_by = scaler.scale_[12]
added = scaler.min_[12]

scaled_train_df = pd.DataFrame(scaled_train, columns=x.columns.values)
# Out:
# Note: median values were scaled by multiplying by 0.4514933346 and adding 0.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
for i in scaled_train_df:
    scaled_train_df[i].hist()
    plt.show()

# %%
from time import time
from tensorflow.keras.callbacks import TensorBoard
tb = TensorBoard(log_dir=f"logs\\{time()}")

# %%
model = tf.keras.Sequential()

# 300 represents number of neurons - 5 layers
model.add(layers.Dense(300, activation='tanh'))
model.add(layers.Dense(300, activation='tanh'))
model.add(layers.Dense(300, activation='tanh'))
model.add(layers.Dense(300, activation='tanh'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
#SGD is Schocastic Gradient Descent
model.compile(optimizer='sgd',
              loss='mean_squared_error',
              metrics=['mean_squared_error'])

# %%
# Code is not working yet.  Need to set Target
model.fit(scaled_train_df.values, np.asarray(y), epochs=5, batch_size=100000, callbacks=[tb])
# Out:
# Epoch 1/5
# 1050000/1050000 [==============================] - 28s 27us/step - loss: 0.2500 - mean_squared_error: 0.2500
# Epoch 2/5
# 1050000/1050000 [==============================] - 28s 27us/step - loss: 0.2499 - mean_squared_error: 0.2499
# Epoch 3/5
# 1050000/1050000 [==============================] - 26s 24us/step - loss: 0.2498 - mean_squared_error: 0.2498
# Epoch 4/5
# 1050000/1050000 [==============================] - 26s 25us/step - loss: 0.2497 - mean_squared_error: 0.2497
# Epoch 5/5
# 1050000/1050000 [==============================] - 27s 26us/step - loss: 0.2496 - mean_squared_error: 0.2496
